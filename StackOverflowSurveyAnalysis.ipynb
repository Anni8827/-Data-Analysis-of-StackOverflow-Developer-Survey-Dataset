# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
survey_raw_df = pd.read_csv(r'survey_results_public.csv')
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
survey_raw_df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
survey_raw_df.shape
# Out:
# (64461, 61)

# %%
survey_raw_df.at[3667,'ConvertedComp']
# Out:
# 387780.0

# %%
survey_raw_df.sample(3)
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 14957       15006  I am a developer by profession      Yes  32.0         11
# 24810       24902  I am a developer by profession       No  24.0         17
# 34039       34164  I am a developer by profession      Yes  30.0         12
#
#       CompFreq  CompTotal  ConvertedComp        Country          CurrencyDesc  \
# 14957   Yearly    60000.0        60000.0  United States  United States dollar
# 24810  Monthly     8000.0        21996.0         Brazil        Brazilian real
# 34039  Monthly     9000.0       116748.0        Finland         European Euro
#
#        ... SurveyEase           SurveyLength Trans  \
# 14957  ...       Easy  Appropriate in length    No
# 24810  ...       Easy  Appropriate in length    No
# 34039  ...       Easy  Appropriate in length    No
#
#                                           UndergradMajor  \
# 14957                          Mathematics or statistics
# ...

# %%
schema_raw=pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
schema_raw
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
survey_raw_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
schema_raw.loc['NEWOtherComms'].QuestionText
# Out:
# 'Are you a member of any other online developer communities?'

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
survey=survey_raw_df[selected_columns]
schema=schema_raw.loc[selected_columns]
schema
# Out:
#                                                              QuestionText
# Column
# Country                                                Where do you live?
# Age                     What is your age (in years)? If you prefer not...
# Gender                  Which of the following describe you, if any? P...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor                      What was your primary field of study?
# Hobbyist                                          Do you code as a hobby?
# Age1stCode              At what age did you write your first line of c...
# YearsCode               Including any education, how many years have y...
# YearsCodePro            NOT including education, how many years have y...
# LanguageWorkedWith      Which programming, scripting, and markup langu...
# LanguageDesireNextYear  Which programming, scripting, and markup langu...
# NEWLearn                How frequently do you learn a new language or ...
# ...

# %%
survey
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
Columns=schema_raw.loc[selected_columns].QuestionText

# %%
Columns.loc['Employment']
# Out:
# 'Which of the following best describes your current employment status?'

# %%
Columns.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 20 entries, Country to NEWEdImpt
# Series name: QuestionText
# Non-Null Count  Dtype
# --------------  -----
# 20 non-null     object
# dtypes: object(1)
# memory usage: 876.0+ bytes

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
survey.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %%
survey.YearsCode.unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
survey.YearsCodePro.unique()
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %%
survey['Age1stCode']=pd.to_numeric(survey.Age1stCode, errors='coerce')
survey['YearsCode']=pd.to_numeric(survey.YearsCode, errors='coerce')
survey['YearsCodePro']=pd.to_numeric(survey.YearsCodePro, errors='coerce')
# Out:
# C:\Users\Aniket Tiwari\AppData\Local\Temp\ipykernel_16932\3217921943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey['Age1stCode']=pd.to_numeric(survey.Age1stCode, errors='coerce')
# C:\Users\Aniket Tiwari\AppData\Local\Temp\ipykernel_16932\3217921943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey['YearsCode']=pd.to_numeric(survey.YearsCode, errors='coerce')
# C:\Users\Aniket Tiwari\AppData\Local\Temp\ipykernel_16932\3217921943.py:3: SettingWithCopyWarning:
# ...

# %%
survey.drop(survey[survey.Age<10].index, inplace=True)
survey.drop(survey[survey.Age>100].index, inplace=True)
survey.drop(survey[survey. WorkWeekHrs>140].index, inplace=True)
# Out:
# C:\Users\Aniket Tiwari\AppData\Local\Temp\ipykernel_16932\3601567202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey.drop(survey[survey.Age<10].index, inplace=True)
# C:\Users\Aniket Tiwari\AppData\Local\Temp\ipykernel_16932\3601567202.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey.drop(survey[survey.Age>100].index, inplace=True)
# C:\Users\Aniket Tiwari\AppData\Local\Temp\ipykernel_16932\3601567202.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
survey.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45319.000000  57326.000000  56636.000000  43993.000000  41002.000000
# mean      30.832322     15.475317     12.783883      8.873003     40.024395
# std        9.505965      5.114952      9.494519      7.762089     10.630010
# min       10.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     43.000000
# max       99.000000     85.000000     50.000000     50.000000    140.000000

# %%
survey['Gender'].value_counts()
# Out:
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: Gender, dtype: int64

# %%
survey.where(~(survey.Gender.str.contains(';', na=False)), np.nan, inplace=True)
# Out:
# C:\Users\Aniket Tiwari\AppData\Local\Temp\ipykernel_16932\1551592807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey.where(~(survey.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size']= 11
matplotlib.rcParams['figure.figsize']= (9,5)
matplotlib.rcParams['figure.facecolor']= '#00000000'

# %% [markdown]
# # Country

# %%
survey.Country.nunique()
# Out:
# 183

# %%
TopCountry = survey.Country.value_counts().head(15)
TopCountry
# Out:
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,5))
plt.xticks(rotation=75)
sns.barplot(x=TopCountry.index, y=TopCountry);
plt.ylabel('Number of Coders')
plt.xlabel('Country')
# Out:
# Text(0.5, 0, 'Country')

# %%
plt.figure(figsize=(12,5))
plt.ylabel('Number of Coders')
plt.xlabel('Age')
plt.hist(survey.Age , bins= np.arange(10,80,5), color= 'Orange')
# Out:
# (array([  209.,  2419.,  9135., 11938.,  8739.,  5582.,  3031.,  1756.,
#          1038.,   622.,   333.,   143.,    75.]),
#  array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75]),
#  <BarContainer object of 13 artists>)

# %%
GenderCount=survey.Gender.value_counts()
GenderCount
# Out:
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(12,5))
plt.pie(survey.Gender.value_counts(), labels=GenderCount.index,autopct='%1.1f%%');

# %% [markdown]
# # India Gender Distribution

# %%
survey_ind=survey[survey.Country=='India']
survey_ind
# Out:
#       Country   Age Gender                                            EdLevel  \
# 6       India   NaN    NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 21      India   NaN    Man       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 57      India   NaN    NaN                                                NaN
# 62      India  21.0    Man  Secondary school (e.g. American high school, G...
# 147     India  36.0    Man       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...       ...   ...    ...                                                ...
# 64391   India   NaN    Man       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64398   India   NaN    NaN                Associate degree (A.A., A.S., etc.)
# 64439   India   NaN    Man       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64442   India   NaN    NaN                                                NaN
# 64452   India   NaN    NaN                                                NaN
#
# ...

# %%
Ind_GenderCount=survey_ind.Gender.value_counts()
Ind_GenderCount
# Out:
# Man                                                  4995
# Woman                                                 369
# Non-binary, genderqueer, or gender non-conforming      12
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.pie(survey_ind.Gender.value_counts(), labels=Ind_GenderCount.index,autopct='%1.1f%%');

# %%
sns.countplot(y=survey.EdLevel)
plt.xticks(rotation=75);
#plt.title(schema['EdLevel'])
plt.ylabel(None);

# %%
schema.loc['UndergradMajor']
# Out:
# QuestionText    What was your primary field of study?
# Name: UndergradMajor, dtype: object

# %%
schema
# Out:
#                                                              QuestionText
# Column
# Country                                                Where do you live?
# Age                     What is your age (in years)? If you prefer not...
# Gender                  Which of the following describe you, if any? P...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor                      What was your primary field of study?
# Hobbyist                                          Do you code as a hobby?
# Age1stCode              At what age did you write your first line of c...
# YearsCode               Including any education, how many years have y...
# YearsCodePro            NOT including education, how many years have y...
# LanguageWorkedWith      Which programming, scripting, and markup langu...
# LanguageDesireNextYear  Which programming, scripting, and markup langu...
# NEWLearn                How frequently do you learn a new language or ...
# ...

# %%
Undergrad_pct= survey.UndergradMajor.value_counts()*100/survey.UndergradMajor.count()
Undergrad_pct
# Out:
# Computer science, computer engineering, or software engineering                   61.939193
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       9.354195
# Information systems, information technology, or system administration              7.983168
# A natural science (such as biology, chemistry, physics, etc.)                      4.316561
# Mathematics or statistics                                                          3.627097
# Web development or web design                                                      3.502637
# A business discipline (such as accounting, finance, marketing, etc.)               2.700567
# A humanities discipline (such as literature, history, philosophy, etc.)            1.969616
# A social science (such as anthropology, psychology, political science, etc.)       1.821450
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)     1.412513
# ...

# %%
survey.UndergradMajor.value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   31353
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4735
# Information systems, information technology, or system administration              4041
# A natural science (such as biology, chemistry, physics, etc.)                      2185
# Mathematics or statistics                                                          1836
# Web development or web design                                                      1773
# A business discipline (such as accounting, finance, marketing, etc.)               1367
# A humanities discipline (such as literature, history, philosophy, etc.)             997
# A social science (such as anthropology, psychology, political science, etc.)        922
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      715
# I never declared a major                                                            448
# ...

# %%
sns.barplot(y=Undergrad_pct.index, x=Undergrad_pct)
#plt.xticks(rotation=75);
#plt.title(schema['EdLevel'])
plt.ylabel(None);
plt.xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')

# %%
Employment_pct= survey.Employment.value_counts()*100/survey.Employment.count()
Employment_pct
# Out:
# Employed full-time                                      70.918383
# Student                                                 12.199893
# Independent contractor, freelancer, or self-employed     8.863615
# Not employed, but looking for work                       3.665962
# Employed part-time                                       3.470360
# Not employed, and not looking for work                   0.501625
# Retired                                                  0.380162
# Name: Employment, dtype: float64

# %%
sns.barplot(y=Employment_pct.index, x=Employment_pct)
#plt.xticks(rotation=75);
#plt.title(schema['EdLevel'])
plt.ylabel(None);
plt.xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')
